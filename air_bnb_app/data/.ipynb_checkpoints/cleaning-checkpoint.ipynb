# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
 from sklearn.datasets import make_regression

# %%
# Read the csv file into a pandas DataFrame
abnb = pd.read_csv('clean_listings.csv')
abnb.head()
# Out:
#    Unnamed: 0    id                                       name  host_id  \
# 0           0  2595                      Skylit Midtown Castle     2845
# 1           1  3831            Cozy Entire Floor of Brownstone     4869
# 2           2  5099  Large Cozy 1 BR Apartment In Midtown East     7322
# 3           3  5121                            BlissArtsSpace!     7356
# 4           4  5178           Large Furnished Room Near B'way      8967
#
#      host_name neighbourhood_group       neighbourhood  latitude  longitude  \
# 0     Jennifer           Manhattan             Midtown  40.75362  -73.98377
# 1  LisaRoxanne            Brooklyn        Clinton Hill  40.68514  -73.95976
# 2        Chris           Manhattan         Murray Hill  40.74767  -73.97500
# 3        Garon            Brooklyn  Bedford-Stuyvesant  40.68688  -73.95596
# 4     Shunichi           Manhattan      Hell's Kitchen  40.76489  -73.98493
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# 0  Entire home/apt    225              10                 48  2019-11-04
# 1  Entire home/apt     89               1                295  2019-11-22
# 2  Entire home/apt    200               3                 78  2019-10-13
# 3     Private room     60              29                 49  2017-10-05
# 4     Private room     79               2                454  2019-11-21
#
#    reviews_per_month  calculated_host_listings_count  availability_365
# 0               0.39                               1                 1
# 1               4.67                               1                 1
# 2               0.60                               1                19
# 3               0.38                               1               365
# 4               3.52                               1               242

# %%
abnb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50583 entries, 0 to 50582
# Data columns (total 17 columns):
# Unnamed: 0                        50583 non-null int64
# id                                50583 non-null int64
# name                              50566 non-null object
# host_id                           50583 non-null int64
# host_name                         50020 non-null object
# neighbourhood_group               50583 non-null object
# neighbourhood                     50583 non-null object
# latitude                          50583 non-null float64
# longitude                         50583 non-null float64
# room_type                         50583 non-null object
# price                             50583 non-null int64
# minimum_nights                    50583 non-null int64
# number_of_reviews                 50583 non-null int64
# last_review                       40364 non-null object
# reviews_per_month                 40364 non-null float64
# calculated_host_listings_count    50583 non-null int64
# availability_365                  50583 non-null int64
# dtypes: float64(3), int64(8), object(6)
# memory usage: 6.6+ MB

# %%
abnb.describe()
# Out:
#          Unnamed: 0            id       host_id      latitude     longitude  \
# count  50583.000000  5.058300e+04  5.058300e+04  50583.000000  50583.000000
# mean   25296.529644  2.137178e+07  7.893029e+07     40.728748    -73.950763
# std    14606.939240  1.242899e+07  9.095542e+07      0.055010      0.047610
# min        0.000000  2.595000e+03  2.438000e+03     40.499790    -74.247870
# 25%    12645.500000  1.009678e+07  8.924880e+06     40.689545    -73.982930
# 50%    25301.000000  2.154779e+07  3.570849e+07     40.722880    -73.955050
# 75%    37946.500000  3.271741e+07  1.293330e+08     40.763040    -73.934225
# max    50598.000000  4.058402e+07  3.143682e+08     40.916860    -73.712990
#
#               price  minimum_nights  number_of_reviews  reviews_per_month  \
# count  50583.000000    50583.000000       50583.000000       40364.000000
# mean     158.221814        7.531878          24.808888           1.405667
# std      348.133242       22.457003          47.318557           1.695511
# min       10.000000        1.000000           0.000000           0.010000
# 25%       69.000000        1.000000           1.000000           0.190000
# 50%      105.000000        3.000000           6.000000           0.740000
# 75%      175.000000        5.000000          25.000000           2.110000
# max    10000.000000     1250.000000         675.000000          52.630000
#
#        calculated_host_listings_count  availability_365
# count                    50583.000000      50583.000000
# mean                         7.332147        112.771998
# std                         32.762568        135.890353
# min                          1.000000          0.000000
# 25%                          1.000000          0.000000
# 50%                          1.000000         42.000000
# 75%                          2.000000        225.000000
# max                        310.000000        365.000000

# %%
abnb_df = pd.DataFrame(abnb)

# %%
abnb_df = abnb_df.sort_values(by=['price'])
abnb_df.head()
# Out:
#        Unnamed: 0        id  \
# 25915       25925  21869057
# 20724       20724  17979764
# 30224       30234  25839759
# 28999       29009  24412104
# 41629       41639  35642891
#
#                                                     name    host_id  \
# 25915      Spacious 2-bedroom Apt in Heart of Greenpoint   11967922
# 20724                                            Jen Apt   84497333
# 30224  Gigantic Sunny Room in Park Slope-Private Back...  167570251
# 28999                           Cozy feel at home studio   91034542
# 41629                         Beautiful room in Bushwick  268138154
#
#                host_name neighbourhood_group neighbourhood  latitude  \
# 25915  Vishanti & Jeremy            Brooklyn    Greenpoint  40.72421
# 20724           Jennifer           Manhattan          SoHo  40.72237
# 30224             Rachel            Brooklyn   Sunset Park  40.66242
# 28999            Maureen           Manhattan      Kips Bay  40.74408
# 41629              Julio            Brooklyn      Bushwick  40.69640
#
#        longitude        room_type  price  minimum_nights  number_of_reviews  \
# 25915  -73.95364  Entire home/apt     10               1                124
# 20724  -73.99817     Private room     10               5                  2
# 30224  -73.99464  Entire home/apt     10               1                 14
# 28999  -73.97803     Private room     10               5                 53
# 41629  -73.91898     Private room     10               1                  2
#
#       last_review  reviews_per_month  calculated_host_listings_count  \
# 25915  2019-11-25               5.02                               1
# 20724  2017-04-15               0.06                               1
# 30224  2018-10-28               0.77                               1
# 28999  2019-11-17               2.69                               1
# 41629  2019-06-18               0.35                               1
#
#        availability_365
# 25915                50
# 20724                 0
# 30224                 7
# 28999                30
# 41629                 0

# %%
abnb_df.tail()
# Out:
#        Unnamed: 0        id                                        name  \
# 48536       48552  39797068  OYO Times Square, Superior City View Queen
# 48537       48553  39797117             OYO Times Square, Superior King
# 48538       48554  39797190               OYO Times Square, Deluxe King
# 43546       43556  37122162        The Ridge Hotel - Full Standard Room
# 43548       43558  37122502                The Ridge Hotel - Queen Room
#
#          host_id         host_name neighbourhood_group     neighbourhood  \
# 48536  304077493  OYO Times Square           Manhattan  Theater District
# 48537  304077493  OYO Times Square           Manhattan  Theater District
# 48538  304077493  OYO Times Square           Manhattan  Theater District
# 43546  266755066   The Ridge Hotel           Manhattan   Lower East Side
# 43548  266755066   The Ridge Hotel           Manhattan   Lower East Side
#
#        latitude  longitude     room_type  price  minimum_nights  \
# 48536  40.75820  -73.98456  Private room  10000               1
# 48537  40.75808  -73.98479  Private room  10000               1
# 48538  40.75968  -73.98403  Private room  10000               1
# 43546  40.72212  -73.98994  Private room  10000               1
# 43548  40.72335  -73.99021  Private room  10000               1
#
#        number_of_reviews last_review  reviews_per_month  \
# 48536                  0         NaN                NaN
# 48537                  0         NaN                NaN
# 48538                  0         NaN                NaN
# 43546                  0         NaN                NaN
# 43548                  2  2019-11-27                2.0
#
#        calculated_host_listings_count  availability_365
# 48536                               9               337
# 48537                               9               337
# 48538                               9               338
# 43546                               5               332
# 43548                               5               353

# %%
abnb_df_corr = abnb_df.corr()
abnb_df_corr
# Out:
#                                 Unnamed: 0        id   host_id  latitude  \
# Unnamed: 0                        1.000000  0.998982  0.601593 -0.006513
# id                                0.998982  1.000000  0.600382 -0.007226
# host_id                           0.601593  0.600382  1.000000  0.022099
# latitude                         -0.006513 -0.007226  0.022099  1.000000
# longitude                         0.105377  0.106543  0.139028  0.077465
# price                             0.034164  0.032524  0.048836  0.029677
# minimum_nights                   -0.000018  0.000203  0.007501  0.028080
# number_of_reviews                -0.313368 -0.312672 -0.140891 -0.016329
# reviews_per_month                 0.305078  0.303970  0.302098 -0.017211
# calculated_host_listings_count    0.114399  0.116331  0.110705  0.023939
# availability_365                  0.141919  0.140517  0.235601 -0.005635
#
#                                 longitude     price  minimum_nights  \
# Unnamed: 0                       0.105377  0.034164       -0.000018
# id                               0.106543  0.032524        0.000203
# host_id                          0.139028  0.048836        0.007501
# latitude                         0.077465  0.029677        0.028080
# longitude                        1.000000 -0.112694       -0.054913
# price                           -0.112694  1.000000        0.028448
# minimum_nights                  -0.054913  0.028448        1.000000
# number_of_reviews                0.058805 -0.041879       -0.087711
# reviews_per_month                0.158536 -0.024479       -0.126797
# calculated_host_listings_count  -0.109466  0.024014        0.121800
# availability_365                 0.083586  0.064661        0.149217
#
#                                 number_of_reviews  reviews_per_month  \
# Unnamed: 0                              -0.313368           0.305078
# id                                      -0.312672           0.303970
# host_id                                 -0.140891           0.302098
# latitude                                -0.016329          -0.017211
# longitude                                0.058805           0.158536
# price                                   -0.041879          -0.024479
# minimum_nights                          -0.087711          -0.126797
# number_of_reviews                        1.000000           0.558214
# reviews_per_month                        0.558214           1.000000
# calculated_host_listings_count          -0.075058          -0.044544
# availability_365                         0.118009           0.177456
#
#                                 calculated_host_listings_count  \
# Unnamed: 0                                            0.114399
# id                                                    0.116331
# host_id                                               0.110705
# latitude                                              0.023939
# longitude                                            -0.109466
# price                                                 0.024014
# minimum_nights                                        0.121800
# number_of_reviews                                    -0.075058
# reviews_per_month                                    -0.044544
# calculated_host_listings_count                        1.000000
# availability_365                                      0.224970
#
#                                 availability_365
# Unnamed: 0                              0.141919
# id                                      0.140517
# host_id                                 0.235601
# latitude                               -0.005635
# longitude                               0.083586
# price                                   0.064661
# minimum_nights                          0.149217
# number_of_reviews                       0.118009
# reviews_per_month                       0.177456
# calculated_host_listings_count          0.224970
# availability_365                        1.000000

# %%
abnb_nrows = len(abnb_df.index)

abnb_df_50 = abnb_df.iloc[round(abnb_nrows*.25):round(abnb_nrows*.75)]
abnb_df_50.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 25291 entries, 39358 to 45598
# Data columns (total 17 columns):
# Unnamed: 0                        25291 non-null int64
# id                                25291 non-null int64
# name                              25285 non-null object
# host_id                           25291 non-null int64
# host_name                         25002 non-null object
# neighbourhood_group               25291 non-null object
# neighbourhood                     25291 non-null object
# latitude                          25291 non-null float64
# longitude                         25291 non-null float64
# room_type                         25291 non-null object
# price                             25291 non-null int64
# minimum_nights                    25291 non-null int64
# number_of_reviews                 25291 non-null int64
# last_review                       20889 non-null object
# reviews_per_month                 20889 non-null float64
# calculated_host_listings_count    25291 non-null int64
# availability_365                  25291 non-null int64
# dtypes: float64(3), int64(8), object(6)
# memory usage: 3.5+ MB

# %%
abnb_df_50_describe = abnb_df_50.describe()
abnb_df_50_describe
# Out:
#          Unnamed: 0            id       host_id      latitude     longitude  \
# count  25291.000000  2.529100e+04  2.529100e+04  25291.000000  25291.000000
# mean   24088.617413  2.034275e+07  7.078560e+07     40.729316    -73.952064
# std    14573.244492  1.242375e+07  8.673415e+07      0.055307      0.045041
# min        1.000000  3.831000e+03  2.438000e+03     40.499790    -74.247870
# 25%    11280.000000  9.350298e+06  7.270688e+06     40.688755    -73.981900
# 50%    23508.000000  2.023574e+07  2.987144e+07     40.722400    -73.955040
# 75%    36620.500000  3.135474e+07  1.072968e+08     40.765140    -73.937875
# max    50598.000000  4.058402e+07  3.143147e+08     40.916860    -73.725400
#
#               price  minimum_nights  number_of_reviews  reviews_per_month  \
# count  25291.000000    25291.000000       25291.000000       20889.000000
# mean     112.651299        6.766399          27.893796           1.411428
# std       30.520673       20.992256          50.424282           1.697630
# min       69.000000        1.000000           0.000000           0.010000
# 25%       85.000000        1.000000           1.000000           0.190000
# 50%      105.000000        2.000000           7.000000           0.720000
# 75%      140.000000        5.000000          29.000000           2.190000
# max      175.000000     1125.000000         580.000000          52.630000
#
#        calculated_host_listings_count  availability_365
# count                    25291.000000      25291.000000
# mean                         4.607014        103.421968
# std                         22.705827        131.345021
# min                          1.000000          0.000000
# 25%                          1.000000          0.000000
# 50%                          1.000000         29.000000
# 75%                          2.000000        179.000000
# max                        310.000000        365.000000

# %%
abnb_df_50_corr = abnb_df_50.corr()
abnb_df_50_corr
# Out:
#                                 Unnamed: 0        id   host_id  latitude  \
# Unnamed: 0                        1.000000  0.999062  0.582380 -0.015402
# id                                0.999062  1.000000  0.581009 -0.016454
# host_id                           0.582380  0.581009  1.000000  0.019970
# latitude                         -0.015402 -0.016454  0.019970  1.000000
# longitude                         0.120362  0.120825  0.148922  0.091071
# price                            -0.023223 -0.023768 -0.042645  0.005103
# minimum_nights                   -0.021870 -0.022557 -0.015468  0.031944
# number_of_reviews                -0.318349 -0.317582 -0.138886 -0.025709
# reviews_per_month                 0.298520  0.297914  0.290506 -0.038441
# calculated_host_listings_count    0.087707  0.086037  0.112627  0.005301
# availability_365                  0.100876  0.098671  0.217025 -0.019392
#
#                                 longitude     price  minimum_nights  \
# Unnamed: 0                       0.120362 -0.023223       -0.021870
# id                               0.120825 -0.023768       -0.022557
# host_id                          0.148922 -0.042645       -0.015468
# latitude                         0.091071  0.005103        0.031944
# longitude                        1.000000 -0.163412       -0.057596
# price                           -0.163412  1.000000        0.045548
# minimum_nights                  -0.057596  0.045548        1.000000
# number_of_reviews                0.032874 -0.016281       -0.077642
# reviews_per_month                0.152946 -0.047988       -0.123627
# calculated_host_listings_count  -0.104821  0.113622        0.072312
# availability_365                 0.115902  0.029867        0.129742
#
#                                 number_of_reviews  reviews_per_month  \
# Unnamed: 0                              -0.318349           0.298520
# id                                      -0.317582           0.297914
# host_id                                 -0.138886           0.290506
# latitude                                -0.025709          -0.038441
# longitude                                0.032874           0.152946
# price                                   -0.016281          -0.047988
# minimum_nights                          -0.077642          -0.123627
# number_of_reviews                        1.000000           0.565010
# reviews_per_month                        0.565010           1.000000
# calculated_host_listings_count          -0.059874          -0.046108
# availability_365                         0.153112           0.186852
#
#                                 calculated_host_listings_count  \
# Unnamed: 0                                            0.087707
# id                                                    0.086037
# host_id                                               0.112627
# latitude                                              0.005301
# longitude                                            -0.104821
# price                                                 0.113622
# minimum_nights                                        0.072312
# number_of_reviews                                    -0.059874
# reviews_per_month                                    -0.046108
# calculated_host_listings_count                        1.000000
# availability_365                                      0.216645
#
#                                 availability_365
# Unnamed: 0                              0.100876
# id                                      0.098671
# host_id                                 0.217025
# latitude                               -0.019392
# longitude                               0.115902
# price                                   0.029867
# minimum_nights                          0.129742
# number_of_reviews                       0.153112
# reviews_per_month                       0.186852
# calculated_host_listings_count          0.216645
# availability_365                        1.000000

# %%
abnb_df_80 = abnb_df.iloc[round(abnb_nrows*.1):round(abnb_nrows*.9)]
abnb_df_80.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 40467 entries, 21199 to 4316
# Data columns (total 17 columns):
# Unnamed: 0                        40467 non-null int64
# id                                40467 non-null int64
# name                              40454 non-null object
# host_id                           40467 non-null int64
# host_name                         39993 non-null object
# neighbourhood_group               40467 non-null object
# neighbourhood                     40467 non-null object
# latitude                          40467 non-null float64
# longitude                         40467 non-null float64
# room_type                         40467 non-null object
# price                             40467 non-null int64
# minimum_nights                    40467 non-null int64
# number_of_reviews                 40467 non-null int64
# last_review                       32908 non-null object
# reviews_per_month                 32908 non-null float64
# calculated_host_listings_count    40467 non-null int64
# availability_365                  40467 non-null int64
# dtypes: float64(3), int64(8), object(6)
# memory usage: 5.6+ MB

# %%
abnb_df_80_describe = abnb_df_80.describe()
abnb_df_80_describe
# Out:
#          Unnamed: 0            id       host_id      latitude     longitude  \
# count  40467.000000  4.046700e+04  4.046700e+04  40467.000000  40467.000000
# mean   24657.875800  2.083144e+07  7.423009e+07     40.729227    -73.951446
# std    14565.338709  1.240717e+07  8.849803e+07      0.054823      0.046178
# min        0.000000  2.595000e+03  2.438000e+03     40.499790    -74.247870
# 25%    12011.500000  9.778719e+06  7.981240e+06     40.689675    -73.982360
# 50%    24318.000000  2.089598e+07  3.222005e+07     40.722720    -73.955030
# 75%    37159.000000  3.196366e+07  1.167329e+08     40.763920    -73.936560
# max    50598.000000  4.058402e+07  3.143647e+08     40.916860    -73.712990
#
#               price  minimum_nights  number_of_reviews  reviews_per_month  \
# count  40467.000000    40467.000000       40467.000000       32908.000000
# mean     121.058121        7.061828          26.369931           1.410835
# std       55.419996       21.856883          48.858841           1.693149
# min       49.000000        1.000000           0.000000           0.010000
# 25%       75.000000        1.000000           1.000000           0.190000
# 50%      105.000000        2.000000           6.000000           0.730000
# 75%      155.000000        5.000000          27.000000           2.140000
# max      265.000000     1250.000000         638.000000          52.630000
#
#        calculated_host_listings_count  availability_365
# count                    40467.000000      40467.000000
# mean                         6.832184        107.858205
# std                         32.016433        133.775767
# min                          1.000000          0.000000
# 25%                          1.000000          0.000000
# 50%                          1.000000         33.000000
# 75%                          2.000000        194.500000
# max                        310.000000        365.000000

# %%
abnb_df_80_corr = abnb_df_80.corr()
abnb_df_80_corr
# Out:
#                                 Unnamed: 0        id   host_id  latitude  \
# Unnamed: 0                        1.000000  0.999021  0.590400 -0.010194
# id                                0.999021  1.000000  0.589053 -0.010952
# host_id                           0.590400  0.589053  1.000000  0.019745
# latitude                         -0.010194 -0.010952  0.019745  1.000000
# longitude                         0.114072  0.114813  0.150795  0.075873
# price                            -0.011690 -0.012313 -0.038531  0.043856
# minimum_nights                   -0.012402 -0.012629 -0.008575  0.039991
# number_of_reviews                -0.315442 -0.314791 -0.135910 -0.020934
# reviews_per_month                 0.302284  0.301214  0.301878 -0.027790
# calculated_host_listings_count    0.112481  0.113672  0.119997  0.021652
# availability_365                  0.122590  0.120971  0.226916 -0.010274
#
#                                 longitude     price  minimum_nights  \
# Unnamed: 0                       0.114072 -0.011690       -0.012402
# id                               0.114813 -0.012313       -0.012629
# host_id                          0.150795 -0.038531       -0.008575
# latitude                         0.075873  0.043856        0.039991
# longitude                        1.000000 -0.270210       -0.066469
# price                           -0.270210  1.000000        0.048024
# minimum_nights                  -0.066469  0.048024        1.000000
# number_of_reviews                0.051446 -0.041855       -0.082991
# reviews_per_month                0.165995 -0.067745       -0.119787
# calculated_host_listings_count  -0.120629  0.175546        0.111029
# availability_365                 0.097774  0.053042        0.143095
#
#                                 number_of_reviews  reviews_per_month  \
# Unnamed: 0                              -0.315442           0.302284
# id                                      -0.314791           0.301214
# host_id                                 -0.135910           0.301878
# latitude                                -0.020934          -0.027790
# longitude                                0.051446           0.165995
# price                                   -0.041855          -0.067745
# minimum_nights                          -0.082991          -0.119787
# number_of_reviews                        1.000000           0.561471
# reviews_per_month                        0.561471           1.000000
# calculated_host_listings_count          -0.073030          -0.044438
# availability_365                         0.136016           0.187983
#
#                                 calculated_host_listings_count  \
# Unnamed: 0                                            0.112481
# id                                                    0.113672
# host_id                                               0.119997
# latitude                                              0.021652
# longitude                                            -0.120629
# price                                                 0.175546
# minimum_nights                                        0.111029
# number_of_reviews                                    -0.073030
# reviews_per_month                                    -0.044438
# calculated_host_listings_count                        1.000000
# availability_365                                      0.239389
#
#                                 availability_365
# Unnamed: 0                              0.122590
# id                                      0.120971
# host_id                                 0.226916
# latitude                               -0.010274
# longitude                               0.097774
# price                                   0.053042
# minimum_nights                          0.143095
# number_of_reviews                       0.136016
# reviews_per_month                       0.187983
# calculated_host_listings_count          0.239389
# availability_365                        1.000000

# %%
abnb_df_90 = abnb_df.iloc[round(abnb_nrows*.05):round(abnb_nrows*.95)]
abnb_df_90.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 45525 entries, 32076 to 18269
# Data columns (total 17 columns):
# Unnamed: 0                        45525 non-null int64
# id                                45525 non-null int64
# name                              45509 non-null object
# host_id                           45525 non-null int64
# host_name                         45014 non-null object
# neighbourhood_group               45525 non-null object
# neighbourhood                     45525 non-null object
# latitude                          45525 non-null float64
# longitude                         45525 non-null float64
# room_type                         45525 non-null object
# price                             45525 non-null int64
# minimum_nights                    45525 non-null int64
# number_of_reviews                 45525 non-null int64
# last_review                       36798 non-null object
# reviews_per_month                 36798 non-null float64
# calculated_host_listings_count    45525 non-null int64
# availability_365                  45525 non-null int64
# dtypes: float64(3), int64(8), object(6)
# memory usage: 6.3+ MB

# %%
abnb_df_90_describe = abnb_df_90.describe()
abnb_df_90_describe
# Out:
#          Unnamed: 0            id       host_id      latitude     longitude  \
# count  45525.000000  4.552500e+04  4.552500e+04  45525.000000  45525.000000
# mean   24940.929248  2.107209e+07  7.603238e+07     40.729028    -73.951078
# std    14572.440131  1.240783e+07  8.934109e+07      0.054781      0.046847
# min        0.000000  2.595000e+03  2.438000e+03     40.499790    -74.247870
# 25%    12290.000000  9.915508e+06  8.343891e+06     40.689700    -73.982630
# 50%    24743.000000  2.119541e+07  3.368719e+07     40.722560    -73.954990
# 75%    37484.000000  3.231064e+07  1.207625e+08     40.763460    -73.935410
# max    50598.000000  4.058402e+07  3.143682e+08     40.916860    -73.712990
#
#               price  minimum_nights  number_of_reviews  reviews_per_month  \
# count  45525.000000    45525.000000       45525.000000       36798.000000
# mean     127.001823        7.276156          25.796991           1.414226
# std       70.267066       21.867415          48.476792           1.705181
# min       40.000000        1.000000           0.000000           0.010000
# 25%       70.000000        1.000000           1.000000           0.190000
# 50%      105.000000        2.000000           6.000000           0.740000
# 75%      167.000000        5.000000          27.000000           2.140000
# max      350.000000     1250.000000         675.000000          52.630000
#
#        calculated_host_listings_count  availability_365
# count                    45525.000000      45525.000000
# mean                         7.304206        109.552202
# std                         33.412752        134.452458
# min                          1.000000          0.000000
# 25%                          1.000000          0.000000
# 50%                          1.000000         36.000000
# 75%                          2.000000        209.000000
# max                        310.000000        365.000000

# %%
abnb_df_90_corr = abnb_df_90.corr()
corr = abnb_df_90.loc[:,abnb_df_90.dtypes == 'float64'].corr()
abnb_df_90_corr
# Out:
#                                 Unnamed: 0        id   host_id  latitude  \
# Unnamed: 0                        1.000000  0.999004  0.593741 -0.006329
# id                                0.999004  1.000000  0.592544 -0.007132
# host_id                           0.593741  0.592544  1.000000  0.024281
# latitude                         -0.006329 -0.007132  0.024281  1.000000
# longitude                         0.107516  0.108378  0.147393  0.076624
# price                             0.011782  0.010733 -0.014033  0.057544
# minimum_nights                   -0.004464 -0.004461  0.000605  0.033018
# number_of_reviews                -0.313062 -0.312398 -0.136194 -0.017008
# reviews_per_month                 0.303957  0.302947  0.304928 -0.020652
# calculated_host_listings_count    0.117512  0.119143  0.117352  0.022691
# availability_365                  0.129125  0.127659  0.231229 -0.003465
#
#                                 longitude     price  minimum_nights  \
# Unnamed: 0                       0.107516  0.011782       -0.004464
# id                               0.108378  0.010733       -0.004461
# host_id                          0.147393 -0.014033        0.000605
# latitude                         0.076624  0.057544        0.033018
# longitude                        1.000000 -0.288807       -0.064618
# price                           -0.288807  1.000000        0.034641
# minimum_nights                  -0.064618  0.034641        1.000000
# number_of_reviews                0.057763 -0.046004       -0.086023
# reviews_per_month                0.164361 -0.046225       -0.122764
# calculated_host_listings_count  -0.119560  0.160648        0.120836
# availability_365                 0.093401  0.071160        0.148736
#
#                                 number_of_reviews  reviews_per_month  \
# Unnamed: 0                              -0.313062           0.303957
# id                                      -0.312398           0.302947
# host_id                                 -0.136194           0.304928
# latitude                                -0.017008          -0.020652
# longitude                                0.057763           0.164361
# price                                   -0.046004          -0.046225
# minimum_nights                          -0.086023          -0.122764
# number_of_reviews                        1.000000           0.562395
# reviews_per_month                        0.562395           1.000000
# calculated_host_listings_count          -0.075513          -0.044048
# availability_365                         0.129657           0.186421
#
#                                 calculated_host_listings_count  \
# Unnamed: 0                                            0.117512
# id                                                    0.119143
# host_id                                               0.117352
# latitude                                              0.022691
# longitude                                            -0.119560
# price                                                 0.160648
# minimum_nights                                        0.120836
# number_of_reviews                                    -0.075513
# reviews_per_month                                    -0.044048
# calculated_host_listings_count                        1.000000
# availability_365                                      0.233845
#
#                                 availability_365
# Unnamed: 0                              0.129125
# id                                      0.127659
# host_id                                 0.231229
# latitude                               -0.003465
# longitude                               0.093401
# price                                   0.071160
# minimum_nights                          0.148736
# number_of_reviews                       0.129657
# reviews_per_month                       0.186421
# calculated_host_listings_count          0.233845
# availability_365                        1.000000

# %%
abnb_df_90.to_csv(r'abnb_df_90.csv')

# %%
abnb_df_80.to_csv(r'abnb_df_80.csv')

# %%
abnb_df_50.to_csv(r'abnb_df_50.csv')

# %%
# Create an completely empty Dataframe without any column names, indices or data
abnb_df_corr_comparison = pd.DataFrame(columns=['100_percent', '90_percent', '80_percent','50_percent'],
                                       index=['Unnamed: 0', 'id', 'host_id', 'latitude', 'longitude',
                                             'price', 'minimum_nights', 'number_of_reviews',
                                              'reviews_per_month','calculated_host_listings_count',
                                             'availability_365'])
abnb_df_corr_comparison['100_percent'] = abnb_df_corr.price
abnb_df_corr_comparison['90_percent'] = abnb_df_90_corr.price
abnb_df_corr_comparison['80_percent'] = abnb_df_80_corr.price
abnb_df_corr_comparison['50_percent'] = abnb_df_50_corr.price
abnb_df_corr_comparison
# Out:
#                                 100_percent  90_percent  80_percent  \
# Unnamed: 0                         0.034164    0.011782   -0.011690
# id                                 0.032524    0.010733   -0.012313
# host_id                            0.048836   -0.014033   -0.038531
# latitude                           0.029677    0.057544    0.043856
# longitude                         -0.112694   -0.288807   -0.270210
# price                              1.000000    1.000000    1.000000
# minimum_nights                     0.028448    0.034641    0.048024
# number_of_reviews                 -0.041879   -0.046004   -0.041855
# reviews_per_month                 -0.024479   -0.046225   -0.067745
# calculated_host_listings_count     0.024014    0.160648    0.175546
# availability_365                   0.064661    0.071160    0.053042
#
#                                 50_percent
# Unnamed: 0                       -0.023223
# id                               -0.023768
# host_id                          -0.042645
# latitude                          0.005103
# longitude                        -0.163412
# price                             1.000000
# minimum_nights                    0.045548
# number_of_reviews                -0.016281
# reviews_per_month                -0.047988
# calculated_host_listings_count    0.113622
# availability_365                  0.029867

# %%
abnb_df_corr_comparison = abnb_df_corr_comparison.drop(['price'])
abnb_df_corr_comparison
# Out:
#                                 100_percent  90_percent  80_percent  \
# Unnamed: 0                         0.034164    0.011782   -0.011690
# id                                 0.032524    0.010733   -0.012313
# host_id                            0.048836   -0.014033   -0.038531
# latitude                           0.029677    0.057544    0.043856
# longitude                         -0.112694   -0.288807   -0.270210
# minimum_nights                     0.028448    0.034641    0.048024
# number_of_reviews                 -0.041879   -0.046004   -0.041855
# reviews_per_month                 -0.024479   -0.046225   -0.067745
# calculated_host_listings_count     0.024014    0.160648    0.175546
# availability_365                   0.064661    0.071160    0.053042
#
#                                 50_percent
# Unnamed: 0                       -0.023223
# id                               -0.023768
# host_id                          -0.042645
# latitude                          0.005103
# longitude                        -0.163412
# minimum_nights                    0.045548
# number_of_reviews                -0.016281
# reviews_per_month                -0.047988
# calculated_host_listings_count    0.113622
# availability_365                  0.029867

# %%
abnb_df_corr_comparison.to_csv(r'abnb_df_corr_comparison.csv')

# %%
ax = abnb_df_corr_comparison.plot.bar()
ax.figure.savefig('price_corr_diff_percent_sample.png')

# %%
import seaborn as sns

ax2 = sns.heatmap(abnb_df_90_corr, xticklabels=abnb_df_90_corr.columns,
            yticklabels=abnb_df_90_corr.columns,
            cmap=sns.diverging_palette(220, 10, as_cmap=True))

ax2.figure.savefig('price_corr90_heat_map.png')

# %%
ax3 = sns.pairplot(abnb_df_90.iloc[round(abnb_nrows*.1):round(abnb_nrows*.9)])
ax3.savefig('price_corr90_pair_plot.png')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-63-8c87eccd093c> in <module>
#       1 ax3 = sns.pairplot(abnb_df_90.iloc[round(abnb_nrows*.1):round(abnb_nrows*.9)])
# ----> 2 ax3.figure.savefig('price_corr90_pair_plot.png')
#
# AttributeError: 'PairGrid' object has no attribute 'figure'
