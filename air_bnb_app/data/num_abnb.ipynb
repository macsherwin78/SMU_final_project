# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
 from sklearn.datasets import make_regression

# %%
# Read the csv file into a pandas DataFrame
abnb = pd.read_csv('ABB_ML_ready.csv')
abnb.head()
# Out:
#    Unnamed: 0  price  minimum_nights  availability_365  number_of_reviews  \
# 0           0    225              10                 1                 48
# 1           1     89               1                 1                295
# 2           2    200               3                19                 78
# 3           3     60              29               365                 49
# 4           4     79               2               242                454
#
#    neighbourhood_group_Bronx  neighbourhood_group_Brooklyn  \
# 0                          0                             0
# 1                          0                             1
# 2                          0                             0
# 3                          0                             1
# 4                          0                             0
#
#    neighbourhood_group_Manhattan  neighbourhood_group_Queens  \
# 0                              1                           0
# 1                              0                           0
# 2                              1                           0
# 3                              0                           0
# 4                              1                           0
#
#    neighbourhood_group_Staten Island  room_type_Entire home/apt  \
# 0                                  0                          1
# 1                                  0                          1
# 2                                  0                          1
# 3                                  0                          0
# 4                                  0                          0
#
#    room_type_Hotel room  room_type_Private room  room_type_Shared room
# 0                     0                       0                      0
# 1                     0                       0                      0
# 2                     0                       0                      0
# 3                     0                       1                      0
# 4                     0                       1                      0

# %%
abnb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50583 entries, 0 to 50582
# Data columns (total 14 columns):
# Unnamed: 0                           50583 non-null int64
# price                                50583 non-null int64
# minimum_nights                       50583 non-null int64
# availability_365                     50583 non-null int64
# number_of_reviews                    50583 non-null int64
# neighbourhood_group_Bronx            50583 non-null int64
# neighbourhood_group_Brooklyn         50583 non-null int64
# neighbourhood_group_Manhattan        50583 non-null int64
# neighbourhood_group_Queens           50583 non-null int64
# neighbourhood_group_Staten Island    50583 non-null int64
# room_type_Entire home/apt            50583 non-null int64
# room_type_Hotel room                 50583 non-null int64
# room_type_Private room               50583 non-null int64
# room_type_Shared room                50583 non-null int64
# dtypes: int64(14)
# memory usage: 5.4 MB

# %%
abnb.describe()
# Out:
#         Unnamed: 0         price  minimum_nights  availability_365  \
# count  50583.00000  50583.000000    50583.000000      50583.000000
# mean   25291.00000    158.221814        7.531878        112.771998
# std    14602.19867    348.133242       22.457003        135.890353
# min        0.00000     10.000000        1.000000          0.000000
# 25%    12645.50000     69.000000        1.000000          0.000000
# 50%    25291.00000    105.000000        3.000000         42.000000
# 75%    37936.50000    175.000000        5.000000        225.000000
# max    50582.00000  10000.000000     1250.000000        365.000000
#
#        number_of_reviews  neighbourhood_group_Bronx  \
# count       50583.000000               50583.000000
# mean           24.808888                   0.024020
# std            47.318557                   0.153112
# min             0.000000                   0.000000
# 25%             1.000000                   0.000000
# 50%             6.000000                   0.000000
# 75%            25.000000                   0.000000
# max           675.000000                   1.000000
#
#        neighbourhood_group_Brooklyn  neighbourhood_group_Manhattan  \
# count                  50583.000000                   50583.000000
# mean                       0.409802                       0.436214
# std                        0.491802                       0.495920
# min                        0.000000                       0.000000
# 25%                        0.000000                       0.000000
# 50%                        0.000000                       0.000000
# 75%                        1.000000                       1.000000
# max                        1.000000                       1.000000
#
#        neighbourhood_group_Queens  neighbourhood_group_Staten Island  \
# count                50583.000000                       50583.000000
# mean                     0.122492                           0.007473
# std                      0.327856                           0.086123
# min                      0.000000                           0.000000
# 25%                      0.000000                           0.000000
# 50%                      0.000000                           0.000000
# 75%                      0.000000                           0.000000
# max                      1.000000                           1.000000
#
#        room_type_Entire home/apt  room_type_Hotel room  \
# count               50583.000000          50583.000000
# mean                    0.516636              0.008244
# std                     0.499728              0.090422
# min                     0.000000              0.000000
# 25%                     0.000000              0.000000
# 50%                     1.000000              0.000000
# 75%                     1.000000              0.000000
# max                     1.000000              1.000000
#
#        room_type_Private room  room_type_Shared room
# count            50583.000000           50583.000000
# mean                 0.450329               0.024791
# std                  0.497532               0.155489
# min                  0.000000               0.000000
# 25%                  0.000000               0.000000
# 50%                  0.000000               0.000000
# 75%                  1.000000               0.000000
# max                  1.000000               1.000000

# %%
abnb_df = pd.DataFrame(abnb)

# %%
abnb_df = abnb_df.sort_values(by=['price'])
abnb_df.head()
# Out:
#        Unnamed: 0  price  minimum_nights  availability_365  number_of_reviews  \
# 25915       25915     10               1                50                124
# 20724       20724     10               5                 0                  2
# 30224       30224     10               1                 7                 14
# 28999       28999     10               5                30                 53
# 41629       41629     10               1                 0                  2
#
#        neighbourhood_group_Bronx  neighbourhood_group_Brooklyn  \
# 25915                          0                             1
# 20724                          0                             0
# 30224                          0                             1
# 28999                          0                             0
# 41629                          0                             1
#
#        neighbourhood_group_Manhattan  neighbourhood_group_Queens  \
# 25915                              0                           0
# 20724                              1                           0
# 30224                              0                           0
# 28999                              1                           0
# 41629                              0                           0
#
#        neighbourhood_group_Staten Island  room_type_Entire home/apt  \
# 25915                                  0                          1
# 20724                                  0                          0
# 30224                                  0                          1
# 28999                                  0                          0
# 41629                                  0                          0
#
#        room_type_Hotel room  room_type_Private room  room_type_Shared room
# 25915                     0                       0                      0
# 20724                     0                       1                      0
# 30224                     0                       0                      0
# 28999                     0                       1                      0
# 41629                     0                       1                      0

# %%
abnb_df.tail()
# Out:
#        Unnamed: 0  price  minimum_nights  availability_365  number_of_reviews  \
# 48536       48536  10000               1               337                  0
# 48537       48537  10000               1               337                  0
# 48538       48538  10000               1               338                  0
# 43546       43546  10000               1               332                  0
# 43548       43548  10000               1               353                  2
#
#        neighbourhood_group_Bronx  neighbourhood_group_Brooklyn  \
# 48536                          0                             0
# 48537                          0                             0
# 48538                          0                             0
# 43546                          0                             0
# 43548                          0                             0
#
#        neighbourhood_group_Manhattan  neighbourhood_group_Queens  \
# 48536                              1                           0
# 48537                              1                           0
# 48538                              1                           0
# 43546                              1                           0
# 43548                              1                           0
#
#        neighbourhood_group_Staten Island  room_type_Entire home/apt  \
# 48536                                  0                          0
# 48537                                  0                          0
# 48538                                  0                          0
# 43546                                  0                          0
# 43548                                  0                          0
#
#        room_type_Hotel room  room_type_Private room  room_type_Shared room
# 48536                     0                       1                      0
# 48537                     0                       1                      0
# 48538                     0                       1                      0
# 43546                     0                       1                      0
# 43548                     0                       1                      0

# %%
abnb_df_corr = abnb_df.corr()
abnb_df_corr
# Out:
#                                    Unnamed: 0     price  minimum_nights  \
# Unnamed: 0                           1.000000  0.034164       -0.000019
# price                                0.034164  1.000000        0.028448
# minimum_nights                      -0.000019  0.028448        1.000000
# availability_365                     0.141917  0.064661        0.149217
# number_of_reviews                   -0.313375 -0.041879       -0.087711
# neighbourhood_group_Bronx            0.051623 -0.032118       -0.020211
# neighbourhood_group_Brooklyn        -0.056080 -0.080834       -0.041114
# neighbourhood_group_Manhattan       -0.025715  0.133342        0.065403
# neighbourhood_group_Queens           0.095326 -0.061973       -0.024455
# neighbourhood_group_Staten Island    0.013647 -0.013201       -0.012798
# room_type_Entire home/apt           -0.057592  0.152405        0.061544
# room_type_Hotel room                 0.063977  0.028210       -0.020512
# room_type_Private room               0.026438 -0.146636       -0.058765
# room_type_Shared room                0.063297 -0.037019        0.002169
#
#                                    availability_365  number_of_reviews  \
# Unnamed: 0                                 0.141917          -0.313375
# price                                      0.064661          -0.041879
# minimum_nights                             0.149217          -0.087711
# availability_365                           1.000000           0.118009
# number_of_reviews                          0.118009           1.000000
# neighbourhood_group_Bronx                  0.060399           0.008522
# neighbourhood_group_Brooklyn              -0.085536           0.017175
# neighbourhood_group_Manhattan              0.005809          -0.050022
# neighbourhood_group_Queens                 0.078779           0.040401
# neighbourhood_group_Staten Island          0.047725           0.021012
# room_type_Entire home/apt                 -0.002021          -0.005940
# room_type_Hotel room                       0.112326          -0.018604
# room_type_Private room                    -0.036651           0.017530
# room_type_Shared room                      0.058450          -0.026183
#
#                                    neighbourhood_group_Bronx  \
# Unnamed: 0                                          0.051623
# price                                              -0.032118
# minimum_nights                                     -0.020211
# availability_365                                    0.060399
# number_of_reviews                                   0.008522
# neighbourhood_group_Bronx                           1.000000
# neighbourhood_group_Brooklyn                       -0.130723
# neighbourhood_group_Manhattan                      -0.137993
# neighbourhood_group_Queens                         -0.058613
# neighbourhood_group_Staten Island                  -0.013612
# room_type_Entire home/apt                          -0.050827
# room_type_Hotel room                               -0.014303
# room_type_Private room                              0.044339
# room_type_Shared room                               0.029794
#
#                                    neighbourhood_group_Brooklyn  \
# Unnamed: 0                                            -0.056080
# price                                                 -0.080834
# minimum_nights                                        -0.041114
# availability_365                                      -0.085536
# number_of_reviews                                      0.017175
# neighbourhood_group_Bronx                             -0.130723
# neighbourhood_group_Brooklyn                           1.000000
# neighbourhood_group_Manhattan                         -0.732960
# neighbourhood_group_Queens                            -0.311326
# neighbourhood_group_Staten Island                     -0.072304
# room_type_Entire home/apt                             -0.068082
# room_type_Hotel room                                  -0.056855
# room_type_Private room                                 0.080080
# room_type_Shared room                                 -0.004367
#
#                                    neighbourhood_group_Manhattan  \
# Unnamed: 0                                             -0.025715
# price                                                   0.133342
# minimum_nights                                          0.065403
# availability_365                                        0.005809
# number_of_reviews                                      -0.050022
# neighbourhood_group_Bronx                              -0.137993
# neighbourhood_group_Brooklyn                           -0.732960
# neighbourhood_group_Manhattan                           1.000000
# neighbourhood_group_Queens                             -0.328640
# neighbourhood_group_Staten Island                      -0.076325
# room_type_Entire home/apt                               0.158065
# room_type_Hotel room                                    0.068380
# room_type_Private room                                 -0.165020
# room_type_Shared room                                  -0.019745
#
#                                    neighbourhood_group_Queens  \
# Unnamed: 0                                           0.095326
# price                                               -0.061973
# minimum_nights                                      -0.024455
# availability_365                                     0.078779
# number_of_reviews                                    0.040401
# neighbourhood_group_Bronx                           -0.058613
# neighbourhood_group_Brooklyn                        -0.311326
# neighbourhood_group_Manhattan                       -0.328640
# neighbourhood_group_Queens                           1.000000
# neighbourhood_group_Staten Island                   -0.032419
# room_type_Entire home/apt                           -0.113074
# room_type_Hotel room                                -0.009389
# room_type_Private room                               0.107717
# room_type_Shared room                                0.024198
#
#                                    neighbourhood_group_Staten Island  \
# Unnamed: 0                                                  0.013647
# price                                                      -0.013201
# minimum_nights                                             -0.012798
# availability_365                                            0.047725
# number_of_reviews                                           0.021012
# neighbourhood_group_Bronx                                  -0.013612
# neighbourhood_group_Brooklyn                               -0.072304
# neighbourhood_group_Manhattan                              -0.076325
# neighbourhood_group_Queens                                 -0.032419
# neighbourhood_group_Staten Island                           1.000000
# room_type_Entire home/apt                                  -0.000592
# room_type_Hotel room                                       -0.007911
# room_type_Private room                                      0.004049
# room_type_Shared room                                      -0.006453
#
#                                    room_type_Entire home/apt  \
# Unnamed: 0                                         -0.057592
# price                                               0.152405
# minimum_nights                                      0.061544
# availability_365                                   -0.002021
# number_of_reviews                                  -0.005940
# neighbourhood_group_Bronx                          -0.050827
# neighbourhood_group_Brooklyn                       -0.068082
# neighbourhood_group_Manhattan                       0.158065
# neighbourhood_group_Queens                         -0.113074
# neighbourhood_group_Staten Island                  -0.000592
# room_type_Entire home/apt                           1.000000
# room_type_Hotel room                               -0.094258
# room_type_Private room                             -0.935770
# room_type_Shared room                              -0.164836
#
#                                    room_type_Hotel room  \
# Unnamed: 0                                     0.063977
# price                                          0.028210
# minimum_nights                                -0.020512
# availability_365                               0.112326
# number_of_reviews                             -0.018604
# neighbourhood_group_Bronx                     -0.014303
# neighbourhood_group_Brooklyn                  -0.056855
# neighbourhood_group_Manhattan                  0.068380
# neighbourhood_group_Queens                    -0.009389
# neighbourhood_group_Staten Island             -0.007911
# room_type_Entire home/apt                     -0.094258
# room_type_Hotel room                           1.000000
# room_type_Private room                        -0.082523
# room_type_Shared room                         -0.014537
#
#                                    room_type_Private room  \
# Unnamed: 0                                       0.026438
# price                                           -0.146636
# minimum_nights                                  -0.058765
# availability_365                                -0.036651
# number_of_reviews                                0.017530
# neighbourhood_group_Bronx                        0.044339
# neighbourhood_group_Brooklyn                     0.080080
# neighbourhood_group_Manhattan                   -0.165020
# neighbourhood_group_Queens                       0.107717
# neighbourhood_group_Staten Island                0.004049
# room_type_Entire home/apt                       -0.935770
# room_type_Hotel room                            -0.082523
# room_type_Private room                           1.000000
# room_type_Shared room                           -0.144315
#
#                                    room_type_Shared room
# Unnamed: 0                                      0.063297
# price                                          -0.037019
# minimum_nights                                  0.002169
# availability_365                                0.058450
# number_of_reviews                              -0.026183
# neighbourhood_group_Bronx                       0.029794
# neighbourhood_group_Brooklyn                   -0.004367
# neighbourhood_group_Manhattan                  -0.019745
# neighbourhood_group_Queens                      0.024198
# neighbourhood_group_Staten Island              -0.006453
# room_type_Entire home/apt                      -0.164836
# room_type_Hotel room                           -0.014537
# room_type_Private room                         -0.144315
# room_type_Shared room                           1.000000

# %%
abnb_nrows = len(abnb_df.index)

abnb_df_50 = abnb_df.iloc[round(abnb_nrows*.25):round(abnb_nrows*.75)]
abnb_df_50.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 25291 entries, 39358 to 45598
# Data columns (total 14 columns):
# Unnamed: 0                           25291 non-null int64
# price                                25291 non-null int64
# minimum_nights                       25291 non-null int64
# availability_365                     25291 non-null int64
# number_of_reviews                    25291 non-null int64
# neighbourhood_group_Bronx            25291 non-null int64
# neighbourhood_group_Brooklyn         25291 non-null int64
# neighbourhood_group_Manhattan        25291 non-null int64
# neighbourhood_group_Queens           25291 non-null int64
# neighbourhood_group_Staten Island    25291 non-null int64
# room_type_Entire home/apt            25291 non-null int64
# room_type_Hotel room                 25291 non-null int64
# room_type_Private room               25291 non-null int64
# room_type_Shared room                25291 non-null int64
# dtypes: int64(14)
# memory usage: 2.9 MB

# %%
abnb_df_50_describe = abnb_df_50.describe()
abnb_df_50_describe
# Out:
#          Unnamed: 0         price  minimum_nights  availability_365  \
# count  25291.000000  25291.000000    25291.000000      25291.000000
# mean   24083.472144    112.651299        6.766399        103.421968
# std    14568.534712     30.520673       20.992256        131.345021
# min        1.000000     69.000000        1.000000          0.000000
# 25%    11280.000000     85.000000        1.000000          0.000000
# 50%    23507.000000    105.000000        2.000000         29.000000
# 75%    36610.500000    140.000000        5.000000        179.000000
# max    50582.000000    175.000000     1125.000000        365.000000
#
#        number_of_reviews  neighbourhood_group_Bronx  \
# count       25291.000000               25291.000000
# mean           27.893796                   0.020323
# std            50.424282                   0.141107
# min             0.000000                   0.000000
# 25%             1.000000                   0.000000
# 50%             7.000000                   0.000000
# 75%            29.000000                   0.000000
# max           580.000000                   1.000000
#
#        neighbourhood_group_Brooklyn  neighbourhood_group_Manhattan  \
# count                  25291.000000                   25291.000000
# mean                       0.418766                       0.440947
# std                        0.493367                       0.496510
# min                        0.000000                       0.000000
# 25%                        0.000000                       0.000000
# 50%                        0.000000                       0.000000
# 75%                        1.000000                       1.000000
# max                        1.000000                       1.000000
#
#        neighbourhood_group_Queens  neighbourhood_group_Staten Island  \
# count                25291.000000                       25291.000000
# mean                     0.112214                           0.007750
# std                      0.315636                           0.087693
# min                      0.000000                           0.000000
# 25%                      0.000000                           0.000000
# 50%                      0.000000                           0.000000
# 75%                      0.000000                           0.000000
# max                      1.000000                           1.000000
#
#        room_type_Entire home/apt  room_type_Hotel room  \
# count               25291.000000          25291.000000
# mean                    0.559408              0.007631
# std                     0.496468              0.087024
# min                     0.000000              0.000000
# 25%                     0.000000              0.000000
# 50%                     1.000000              0.000000
# 75%                     1.000000              0.000000
# max                     1.000000              1.000000
#
#        room_type_Private room  room_type_Shared room
# count            25291.000000           25291.000000
# mean                 0.422206               0.010755
# std                  0.493921               0.103148
# min                  0.000000               0.000000
# 25%                  0.000000               0.000000
# 50%                  0.000000               0.000000
# 75%                  1.000000               0.000000
# max                  1.000000               1.000000

# %%
abnb_df_50_corr = abnb_df_50.corr()
abnb_df_50_corr
# Out:
#                                    Unnamed: 0     price  minimum_nights  \
# Unnamed: 0                           1.000000 -0.023225       -0.021871
# price                               -0.023225  1.000000        0.045548
# minimum_nights                      -0.021871  0.045548        1.000000
# availability_365                     0.100871  0.029867        0.129742
# number_of_reviews                   -0.318357 -0.016281       -0.077642
# neighbourhood_group_Bronx            0.062836 -0.059300       -0.016391
# neighbourhood_group_Brooklyn        -0.041997 -0.065152       -0.045188
# neighbourhood_group_Manhattan       -0.043713  0.148058        0.072915
# neighbourhood_group_Queens           0.097798 -0.095967       -0.032279
# neighbourhood_group_Staten Island    0.030659 -0.030902       -0.016050
# room_type_Entire home/apt           -0.056561  0.468507        0.099578
# room_type_Hotel room                 0.065825  0.010187       -0.015669
# room_type_Private room               0.041567 -0.459760       -0.097161
# room_type_Shared room                0.017656 -0.062049       -0.000812
#
#                                    availability_365  number_of_reviews  \
# Unnamed: 0                                 0.100871          -0.318357
# price                                      0.029867          -0.016281
# minimum_nights                             0.129742          -0.077642
# availability_365                           1.000000           0.153112
# number_of_reviews                          0.153112           1.000000
# neighbourhood_group_Bronx                  0.065101           0.000103
# neighbourhood_group_Brooklyn              -0.056731           0.031895
# neighbourhood_group_Manhattan             -0.027047          -0.037306
# neighbourhood_group_Queens                 0.086672           0.004947
# neighbourhood_group_Staten Island          0.055595           0.013805
# room_type_Entire home/apt                 -0.037180          -0.007102
# room_type_Hotel room                       0.136671          -0.018549
# room_type_Private room                     0.009196           0.014770
# room_type_Shared room                      0.019611          -0.020892
#
#                                    neighbourhood_group_Bronx  \
# Unnamed: 0                                          0.062836
# price                                              -0.059300
# minimum_nights                                     -0.016391
# availability_365                                    0.065101
# number_of_reviews                                   0.000103
# neighbourhood_group_Bronx                           1.000000
# neighbourhood_group_Brooklyn                       -0.122255
# neighbourhood_group_Manhattan                      -0.127916
# neighbourhood_group_Queens                         -0.051207
# neighbourhood_group_Staten Island                  -0.012729
# room_type_Entire home/apt                           0.010986
# room_type_Hotel room                               -0.012630
# room_type_Private room                             -0.011355
# room_type_Shared room                               0.012149
#
#                                    neighbourhood_group_Brooklyn  \
# Unnamed: 0                                            -0.041997
# price                                                 -0.065152
# minimum_nights                                        -0.045188
# availability_365                                      -0.056731
# number_of_reviews                                      0.031895
# neighbourhood_group_Bronx                             -0.122255
# neighbourhood_group_Brooklyn                           1.000000
# neighbourhood_group_Manhattan                         -0.753836
# neighbourhood_group_Queens                            -0.301772
# neighbourhood_group_Staten Island                     -0.075014
# room_type_Entire home/apt                              0.074631
# room_type_Hotel room                                  -0.056014
# room_type_Private room                                -0.055751
# room_type_Shared room                                 -0.044991
#
#                                    neighbourhood_group_Manhattan  \
# Unnamed: 0                                             -0.043713
# price                                                   0.148058
# minimum_nights                                          0.072915
# availability_365                                       -0.027047
# number_of_reviews                                      -0.037306
# neighbourhood_group_Bronx                              -0.127916
# neighbourhood_group_Brooklyn                           -0.753836
# neighbourhood_group_Manhattan                           1.000000
# neighbourhood_group_Queens                             -0.315745
# neighbourhood_group_Staten Island                      -0.078488
# room_type_Entire home/apt                              -0.086866
# room_type_Hotel room                                    0.052983
# room_type_Private room                                  0.068617
# room_type_Shared room                                   0.044829
#
#                                    neighbourhood_group_Queens  \
# Unnamed: 0                                           0.097798
# price                                               -0.095967
# minimum_nights                                      -0.032279
# availability_365                                     0.086672
# number_of_reviews                                    0.004947
# neighbourhood_group_Bronx                           -0.051207
# neighbourhood_group_Brooklyn                        -0.301772
# neighbourhood_group_Manhattan                       -0.315745
# neighbourhood_group_Queens                           1.000000
# neighbourhood_group_Staten Island                   -0.031420
# room_type_Entire home/apt                            0.007418
# room_type_Hotel room                                 0.012010
# room_type_Private room                              -0.008933
# room_type_Shared room                               -0.003063
#
#                                    neighbourhood_group_Staten Island  \
# Unnamed: 0                                                  0.030659
# price                                                      -0.030902
# minimum_nights                                             -0.016050
# availability_365                                            0.055595
# number_of_reviews                                           0.013805
# neighbourhood_group_Bronx                                  -0.012729
# neighbourhood_group_Brooklyn                               -0.075014
# neighbourhood_group_Manhattan                              -0.078488
# neighbourhood_group_Queens                                 -0.031420
# neighbourhood_group_Staten Island                           1.000000
# room_type_Entire home/apt                                   0.027570
# room_type_Hotel room                                       -0.007750
# room_type_Private room                                     -0.024423
# room_type_Shared room                                      -0.009215
#
#                                    room_type_Entire home/apt  \
# Unnamed: 0                                         -0.056561
# price                                               0.468507
# minimum_nights                                      0.099578
# availability_365                                   -0.037180
# number_of_reviews                                  -0.007102
# neighbourhood_group_Bronx                           0.010986
# neighbourhood_group_Brooklyn                        0.074631
# neighbourhood_group_Manhattan                      -0.086866
# neighbourhood_group_Queens                          0.007418
# neighbourhood_group_Staten Island                   0.027570
# room_type_Entire home/apt                           1.000000
# room_type_Hotel room                               -0.098811
# room_type_Private room                             -0.963212
# room_type_Shared room                              -0.117489
#
#                                    room_type_Hotel room  \
# Unnamed: 0                                     0.065825
# price                                          0.010187
# minimum_nights                                -0.015669
# availability_365                               0.136671
# number_of_reviews                             -0.018549
# neighbourhood_group_Bronx                     -0.012630
# neighbourhood_group_Brooklyn                  -0.056014
# neighbourhood_group_Manhattan                  0.052983
# neighbourhood_group_Queens                     0.012010
# neighbourhood_group_Staten Island             -0.007750
# room_type_Entire home/apt                     -0.098811
# room_type_Hotel room                           1.000000
# room_type_Private room                        -0.074961
# room_type_Shared room                         -0.009143
#
#                                    room_type_Private room  \
# Unnamed: 0                                       0.041567
# price                                           -0.459760
# minimum_nights                                  -0.097161
# availability_365                                 0.009196
# number_of_reviews                                0.014770
# neighbourhood_group_Bronx                       -0.011355
# neighbourhood_group_Brooklyn                    -0.055751
# neighbourhood_group_Manhattan                    0.068617
# neighbourhood_group_Queens                      -0.008933
# neighbourhood_group_Staten Island               -0.024423
# room_type_Entire home/apt                       -0.963212
# room_type_Hotel room                            -0.074961
# room_type_Private room                           1.000000
# room_type_Shared room                           -0.089130
#
#                                    room_type_Shared room
# Unnamed: 0                                      0.017656
# price                                          -0.062049
# minimum_nights                                 -0.000812
# availability_365                                0.019611
# number_of_reviews                              -0.020892
# neighbourhood_group_Bronx                       0.012149
# neighbourhood_group_Brooklyn                   -0.044991
# neighbourhood_group_Manhattan                   0.044829
# neighbourhood_group_Queens                     -0.003063
# neighbourhood_group_Staten Island              -0.009215
# room_type_Entire home/apt                      -0.117489
# room_type_Hotel room                           -0.009143
# room_type_Private room                         -0.089130
# room_type_Shared room                           1.000000

# %%
abnb_df_80 = abnb_df.iloc[round(abnb_nrows*.1):round(abnb_nrows*.9)]
abnb_df_80.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 40467 entries, 21199 to 4316
# Data columns (total 14 columns):
# Unnamed: 0                           40467 non-null int64
# price                                40467 non-null int64
# minimum_nights                       40467 non-null int64
# availability_365                     40467 non-null int64
# number_of_reviews                    40467 non-null int64
# neighbourhood_group_Bronx            40467 non-null int64
# neighbourhood_group_Brooklyn         40467 non-null int64
# neighbourhood_group_Manhattan        40467 non-null int64
# neighbourhood_group_Queens           40467 non-null int64
# neighbourhood_group_Staten Island    40467 non-null int64
# room_type_Entire home/apt            40467 non-null int64
# room_type_Hotel room                 40467 non-null int64
# room_type_Private room               40467 non-null int64
# room_type_Shared room                40467 non-null int64
# dtypes: int64(14)
# memory usage: 4.6 MB

# %%
abnb_df_80_describe = abnb_df_80.describe()
abnb_df_80_describe
# Out:
#          Unnamed: 0         price  minimum_nights  availability_365  \
# count  40467.000000  40467.000000    40467.000000      40467.000000
# mean   24652.552771    121.058121        7.061828        107.858205
# std    14560.612466     55.419996       21.856883        133.775767
# min        0.000000     49.000000        1.000000          0.000000
# 25%    12011.500000     75.000000        1.000000          0.000000
# 50%    24311.000000    105.000000        2.000000         33.000000
# 75%    37149.000000    155.000000        5.000000        194.500000
# max    50582.000000    265.000000     1250.000000        365.000000
#
#        number_of_reviews  neighbourhood_group_Bronx  \
# count       40467.000000               40467.000000
# mean           26.369931                   0.021573
# std            48.858841                   0.145287
# min             0.000000                   0.000000
# 25%             1.000000                   0.000000
# 50%             6.000000                   0.000000
# 75%            27.000000                   0.000000
# max           638.000000                   1.000000
#
#        neighbourhood_group_Brooklyn  neighbourhood_group_Manhattan  \
# count                  40467.000000                   40467.000000
# mean                       0.415623                       0.438703
# std                        0.492835                       0.496235
# min                        0.000000                       0.000000
# 25%                        0.000000                       0.000000
# 50%                        0.000000                       0.000000
# 75%                        1.000000                       1.000000
# max                        1.000000                       1.000000
#
#        neighbourhood_group_Queens  neighbourhood_group_Staten Island  \
# count                40467.000000                       40467.000000
# mean                     0.116836                           0.007265
# std                      0.321229                           0.084927
# min                      0.000000                           0.000000
# 25%                      0.000000                           0.000000
# 50%                      0.000000                           0.000000
# 75%                      0.000000                           0.000000
# max                      1.000000                           1.000000
#
#        room_type_Entire home/apt  room_type_Hotel room  \
# count               40467.000000          40467.000000
# mean                    0.533002              0.006895
# std                     0.498916              0.082747
# min                     0.000000              0.000000
# 25%                     0.000000              0.000000
# 50%                     1.000000              0.000000
# 75%                     1.000000              0.000000
# max                     1.000000              1.000000
#
#        room_type_Private room  room_type_Shared room
# count            40467.000000           40467.000000
# mean                 0.447031               0.013072
# std                  0.497193               0.113586
# min                  0.000000               0.000000
# 25%                  0.000000               0.000000
# 50%                  0.000000               0.000000
# 75%                  1.000000               0.000000
# max                  1.000000               1.000000

# %%
abnb_df_80_corr = abnb_df_80.corr()
abnb_df_80_corr
# Out:
#                                    Unnamed: 0     price  minimum_nights  \
# Unnamed: 0                           1.000000 -0.011692       -0.012403
# price                               -0.011692  1.000000        0.048024
# minimum_nights                      -0.012403  0.048024        1.000000
# availability_365                     0.122585  0.053042        0.143095
# number_of_reviews                   -0.315449 -0.041855       -0.082991
# neighbourhood_group_Bronx            0.057523 -0.081743       -0.017167
# neighbourhood_group_Brooklyn        -0.049361 -0.149702       -0.049104
# neighbourhood_group_Manhattan       -0.033946  0.276600        0.083603
# neighbourhood_group_Queens           0.096350 -0.151836       -0.042058
# neighbourhood_group_Staten Island    0.021949 -0.033320       -0.015099
# room_type_Entire home/apt           -0.053257  0.587107        0.090059
# room_type_Hotel room                 0.060116  0.036448       -0.015744
# room_type_Private room               0.038805 -0.577731       -0.085414
# room_type_Shared room                0.020270 -0.076503       -0.010230
#
#                                    availability_365  number_of_reviews  \
# Unnamed: 0                                 0.122585          -0.315449
# price                                      0.053042          -0.041855
# minimum_nights                             0.143095          -0.082991
# availability_365                           1.000000           0.136016
# number_of_reviews                          0.136016           1.000000
# neighbourhood_group_Bronx                  0.066084           0.003555
# neighbourhood_group_Brooklyn              -0.074517           0.022595
# neighbourhood_group_Manhattan             -0.007975          -0.046387
# neighbourhood_group_Queens                 0.083434           0.030330
# neighbourhood_group_Staten Island          0.050395           0.019125
# room_type_Entire home/apt                 -0.016368          -0.009848
# room_type_Hotel room                       0.117021          -0.016077
# room_type_Private room                    -0.008056           0.016439
# room_type_Shared room                      0.021910          -0.016991
#
#                                    neighbourhood_group_Bronx  \
# Unnamed: 0                                          0.057523
# price                                              -0.081743
# minimum_nights                                     -0.017167
# availability_365                                    0.066084
# number_of_reviews                                   0.003555
# neighbourhood_group_Bronx                           1.000000
# neighbourhood_group_Brooklyn                       -0.125226
# neighbourhood_group_Manhattan                      -0.131275
# neighbourhood_group_Queens                         -0.054008
# neighbourhood_group_Staten Island                  -0.012703
# room_type_Entire home/apt                          -0.025675
# room_type_Hotel room                               -0.012372
# room_type_Private room                              0.023859
# room_type_Shared room                               0.017352
#
#                                    neighbourhood_group_Brooklyn  \
# Unnamed: 0                                            -0.049361
# price                                                 -0.149702
# minimum_nights                                        -0.049104
# availability_365                                      -0.074517
# number_of_reviews                                      0.022595
# neighbourhood_group_Bronx                             -0.125226
# neighbourhood_group_Brooklyn                           1.000000
# neighbourhood_group_Manhattan                         -0.745576
# neighbourhood_group_Queens                            -0.306740
# neighbourhood_group_Staten Island                     -0.072146
# room_type_Entire home/apt                             -0.025183
# room_type_Hotel room                                  -0.056330
# room_type_Private room                                 0.045221
# room_type_Shared room                                 -0.046292
#
#                                    neighbourhood_group_Manhattan  \
# Unnamed: 0                                             -0.033946
# price                                                   0.276600
# minimum_nights                                          0.083603
# availability_365                                       -0.007975
# number_of_reviews                                      -0.046387
# neighbourhood_group_Bronx                              -0.131275
# neighbourhood_group_Brooklyn                           -0.745576
# neighbourhood_group_Manhattan                           1.000000
# neighbourhood_group_Queens                             -0.321556
# neighbourhood_group_Staten Island                      -0.075630
# room_type_Entire home/apt                               0.074922
# room_type_Hotel room                                    0.058137
# room_type_Private room                                 -0.094366
# room_type_Shared room                                   0.041618
#
#                                    neighbourhood_group_Queens  \
# Unnamed: 0                                           0.096350
# price                                               -0.151836
# minimum_nights                                      -0.042058
# availability_365                                     0.083434
# number_of_reviews                                    0.030330
# neighbourhood_group_Bronx                           -0.054008
# neighbourhood_group_Brooklyn                        -0.306740
# neighbourhood_group_Manhattan                       -0.321556
# neighbourhood_group_Queens                           1.000000
# neighbourhood_group_Staten Island                   -0.031115
# room_type_Entire home/apt                           -0.069084
# room_type_Hotel room                                 0.004093
# room_type_Private room                               0.068303
# room_type_Shared room                                0.001486
#
#                                    neighbourhood_group_Staten Island  \
# Unnamed: 0                                                  0.021949
# price                                                      -0.033320
# minimum_nights                                             -0.015099
# availability_365                                            0.050395
# number_of_reviews                                           0.019125
# neighbourhood_group_Bronx                                  -0.012703
# neighbourhood_group_Brooklyn                               -0.072146
# neighbourhood_group_Manhattan                              -0.075630
# neighbourhood_group_Queens                                 -0.031115
# neighbourhood_group_Staten Island                           1.000000
# room_type_Entire home/apt                                   0.013588
# room_type_Hotel room                                       -0.007128
# room_type_Private room                                     -0.010199
# room_type_Shared room                                      -0.009846
#
#                                    room_type_Entire home/apt  \
# Unnamed: 0                                         -0.053257
# price                                               0.587107
# minimum_nights                                      0.090059
# availability_365                                   -0.016368
# number_of_reviews                                  -0.009848
# neighbourhood_group_Bronx                          -0.025675
# neighbourhood_group_Brooklyn                       -0.025183
# neighbourhood_group_Manhattan                       0.074922
# neighbourhood_group_Queens                         -0.069084
# neighbourhood_group_Staten Island                   0.013588
# room_type_Entire home/apt                           1.000000
# room_type_Hotel room                               -0.089015
# room_type_Private room                             -0.960562
# room_type_Shared room                              -0.122954
#
#                                    room_type_Hotel room  \
# Unnamed: 0                                     0.060116
# price                                          0.036448
# minimum_nights                                -0.015744
# availability_365                               0.117021
# number_of_reviews                             -0.016077
# neighbourhood_group_Bronx                     -0.012372
# neighbourhood_group_Brooklyn                  -0.056330
# neighbourhood_group_Manhattan                  0.058137
# neighbourhood_group_Queens                     0.004093
# neighbourhood_group_Staten Island             -0.007128
# room_type_Entire home/apt                     -0.089015
# room_type_Hotel room                           1.000000
# room_type_Private room                        -0.074916
# room_type_Shared room                         -0.009589
#
#                                    room_type_Private room  \
# Unnamed: 0                                       0.038805
# price                                           -0.577731
# minimum_nights                                  -0.085414
# availability_365                                -0.008056
# number_of_reviews                                0.016439
# neighbourhood_group_Bronx                        0.023859
# neighbourhood_group_Brooklyn                     0.045221
# neighbourhood_group_Manhattan                   -0.094366
# neighbourhood_group_Queens                       0.068303
# neighbourhood_group_Staten Island               -0.010199
# room_type_Entire home/apt                       -0.960562
# room_type_Hotel room                            -0.074916
# room_type_Private room                           1.000000
# room_type_Shared room                           -0.103479
#
#                                    room_type_Shared room
# Unnamed: 0                                      0.020270
# price                                          -0.076503
# minimum_nights                                 -0.010230
# availability_365                                0.021910
# number_of_reviews                              -0.016991
# neighbourhood_group_Bronx                       0.017352
# neighbourhood_group_Brooklyn                   -0.046292
# neighbourhood_group_Manhattan                   0.041618
# neighbourhood_group_Queens                      0.001486
# neighbourhood_group_Staten Island              -0.009846
# room_type_Entire home/apt                      -0.122954
# room_type_Hotel room                           -0.009589
# room_type_Private room                         -0.103479
# room_type_Shared room                           1.000000

# %%
abnb_df_90 = abnb_df.iloc[round(abnb_nrows*.05):round(abnb_nrows*.95)]
abnb_df_90.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 45525 entries, 32076 to 18269
# Data columns (total 14 columns):
# Unnamed: 0                           45525 non-null int64
# price                                45525 non-null int64
# minimum_nights                       45525 non-null int64
# availability_365                     45525 non-null int64
# number_of_reviews                    45525 non-null int64
# neighbourhood_group_Bronx            45525 non-null int64
# neighbourhood_group_Brooklyn         45525 non-null int64
# neighbourhood_group_Manhattan        45525 non-null int64
# neighbourhood_group_Queens           45525 non-null int64
# neighbourhood_group_Staten Island    45525 non-null int64
# room_type_Entire home/apt            45525 non-null int64
# room_type_Hotel room                 45525 non-null int64
# room_type_Private room               45525 non-null int64
# room_type_Shared room                45525 non-null int64
# dtypes: int64(14)
# memory usage: 5.2 MB

# %%
abnb_df_90_describe = abnb_df_90.describe()
abnb_df_90_describe
# Out:
#          Unnamed: 0         price  minimum_nights  availability_365  \
# count  45525.000000  45525.000000    45525.000000      45525.000000
# mean   24935.515497    127.001823        7.276156        109.552202
# std    14567.709064     70.267066       21.867415        134.452458
# min        0.000000     40.000000        1.000000          0.000000
# 25%    12290.000000     70.000000        1.000000          0.000000
# 50%    24735.000000    105.000000        2.000000         36.000000
# 75%    37474.000000    167.000000        5.000000        209.000000
# max    50582.000000    350.000000     1250.000000        365.000000
#
#        number_of_reviews  neighbourhood_group_Bronx  \
# count       45525.000000               45525.000000
# mean           25.796991                   0.022647
# std            48.476792                   0.148777
# min             0.000000                   0.000000
# 25%             1.000000                   0.000000
# 50%             6.000000                   0.000000
# 75%            27.000000                   0.000000
# max           675.000000                   1.000000
#
#        neighbourhood_group_Brooklyn  neighbourhood_group_Manhattan  \
# count                  45525.000000                   45525.000000
# mean                       0.414278                       0.436442
# std                        0.492602                       0.495949
# min                        0.000000                       0.000000
# 25%                        0.000000                       0.000000
# 50%                        0.000000                       0.000000
# 75%                        1.000000                       1.000000
# max                        1.000000                       1.000000
#
#        neighbourhood_group_Queens  neighbourhood_group_Staten Island  \
# count                45525.000000                       45525.000000
# mean                     0.119495                           0.007139
# std                      0.324373                           0.084191
# min                      0.000000                           0.000000
# 25%                      0.000000                           0.000000
# 50%                      0.000000                           0.000000
# 75%                      0.000000                           0.000000
# max                      1.000000                           1.000000
#
#        room_type_Entire home/apt  room_type_Hotel room  \
# count               45525.000000          45525.000000
# mean                    0.526063              0.007205
# std                     0.499326              0.084576
# min                     0.000000              0.000000
# 25%                     0.000000              0.000000
# 50%                     1.000000              0.000000
# 75%                     1.000000              0.000000
# max                     1.000000              1.000000
#
#        room_type_Private room  room_type_Shared room
# count            45525.000000           45525.000000
# mean                 0.451752               0.014981
# std                  0.497672               0.121477
# min                  0.000000               0.000000
# 25%                  0.000000               0.000000
# 50%                  0.000000               0.000000
# 75%                  1.000000               0.000000
# max                  1.000000               1.000000

# %%
abnb_df_90_corr = abnb_df_90.corr()
corr = abnb_df_90.loc[:,abnb_df_90.dtypes == 'float64'].corr()
abnb_df_90_corr
# Out:
#                                    Unnamed: 0     price  minimum_nights  \
# Unnamed: 0                           1.000000  0.011780       -0.004465
# price                                0.011780  1.000000        0.034641
# minimum_nights                      -0.004465  0.034641        1.000000
# availability_365                     0.129121  0.071160        0.148736
# number_of_reviews                   -0.313069 -0.046004       -0.086023
# neighbourhood_group_Bronx            0.052387 -0.082383       -0.019626
# neighbourhood_group_Brooklyn        -0.056479 -0.167658       -0.042574
# neighbourhood_group_Manhattan       -0.025478  0.303142        0.075998
# neighbourhood_group_Queens           0.095954 -0.162759       -0.038708
# neighbourhood_group_Staten Island    0.018279 -0.032106       -0.014768
# room_type_Entire home/apt           -0.049212  0.586486        0.077810
# room_type_Hotel room                 0.060906  0.051978       -0.017870
# room_type_Private room               0.033621 -0.576767       -0.072641
# room_type_Shared room                0.022138 -0.083990       -0.009794
#
#                                    availability_365  number_of_reviews  \
# Unnamed: 0                                 0.129121          -0.313069
# price                                      0.071160          -0.046004
# minimum_nights                             0.148736          -0.086023
# availability_365                           1.000000           0.129657
# number_of_reviews                          0.129657           1.000000
# neighbourhood_group_Bronx                  0.069301           0.007841
# neighbourhood_group_Brooklyn              -0.084335           0.017733
# neighbourhood_group_Manhattan              0.000313          -0.048856
# neighbourhood_group_Queens                 0.083594           0.039436
# neighbourhood_group_Staten Island          0.047067           0.018246
# room_type_Entire home/apt                 -0.005322          -0.009096
# room_type_Hotel room                       0.110591          -0.017720
# room_type_Private room                    -0.019904           0.015984
# room_type_Shared room                      0.026423          -0.015758
#
#                                    neighbourhood_group_Bronx  \
# Unnamed: 0                                          0.052387
# price                                              -0.082383
# minimum_nights                                     -0.019626
# availability_365                                    0.069301
# number_of_reviews                                   0.007841
# neighbourhood_group_Bronx                           1.000000
# neighbourhood_group_Brooklyn                       -0.128020
# neighbourhood_group_Manhattan                      -0.133959
# neighbourhood_group_Queens                         -0.056077
# neighbourhood_group_Staten Island                  -0.012908
# room_type_Entire home/apt                          -0.037071
# room_type_Hotel room                               -0.012968
# room_type_Private room                              0.034487
# room_type_Shared room                               0.020121
#
#                                    neighbourhood_group_Brooklyn  \
# Unnamed: 0                                            -0.056479
# price                                                 -0.167658
# minimum_nights                                        -0.042574
# availability_365                                      -0.084335
# number_of_reviews                                      0.017733
# neighbourhood_group_Bronx                             -0.128020
# neighbourhood_group_Brooklyn                           1.000000
# neighbourhood_group_Manhattan                         -0.740105
# neighbourhood_group_Queens                            -0.309819
# neighbourhood_group_Staten Island                     -0.071314
# room_type_Entire home/apt                             -0.051220
# room_type_Hotel room                                  -0.057936
# room_type_Private room                                 0.070782
# room_type_Shared room                                 -0.039109
#
#                                    neighbourhood_group_Manhattan  \
# Unnamed: 0                                             -0.025478
# price                                                   0.303142
# minimum_nights                                          0.075998
# availability_365                                        0.000313
# number_of_reviews                                      -0.048856
# neighbourhood_group_Bronx                              -0.133959
# neighbourhood_group_Brooklyn                           -0.740105
# neighbourhood_group_Manhattan                           1.000000
# neighbourhood_group_Queens                             -0.324192
# neighbourhood_group_Staten Island                      -0.074622
# room_type_Entire home/apt                               0.119985
# room_type_Hotel room                                    0.063810
# room_type_Private room                                 -0.138557
# room_type_Shared room                                   0.030024
#
#                                    neighbourhood_group_Queens  \
# Unnamed: 0                                           0.095954
# price                                               -0.162759
# minimum_nights                                      -0.038708
# availability_365                                     0.083594
# number_of_reviews                                    0.039436
# neighbourhood_group_Bronx                           -0.056077
# neighbourhood_group_Brooklyn                        -0.309819
# neighbourhood_group_Manhattan                       -0.324192
# neighbourhood_group_Queens                           1.000000
# neighbourhood_group_Staten Island                   -0.031238
# room_type_Entire home/apt                           -0.090837
# room_type_Hotel room                                -0.001757
# room_type_Private room                               0.089872
# room_type_Shared room                                0.006413
#
#                                    neighbourhood_group_Staten Island  \
# Unnamed: 0                                                  0.018279
# price                                                      -0.032106
# minimum_nights                                             -0.014768
# availability_365                                            0.047067
# number_of_reviews                                           0.018246
# neighbourhood_group_Bronx                                  -0.012908
# neighbourhood_group_Brooklyn                               -0.071314
# neighbourhood_group_Manhattan                              -0.074622
# neighbourhood_group_Queens                                 -0.031238
# neighbourhood_group_Staten Island                           1.000000
# room_type_Entire home/apt                                   0.008376
# room_type_Hotel room                                       -0.007224
# room_type_Private room                                     -0.005148
# room_type_Shared room                                      -0.008309
#
#                                    room_type_Entire home/apt  \
# Unnamed: 0                                         -0.049212
# price                                               0.586486
# minimum_nights                                      0.077810
# availability_365                                   -0.005322
# number_of_reviews                                  -0.009096
# neighbourhood_group_Bronx                          -0.037071
# neighbourhood_group_Brooklyn                       -0.051220
# neighbourhood_group_Manhattan                       0.119985
# neighbourhood_group_Queens                         -0.090837
# neighbourhood_group_Staten Island                   0.008376
# room_type_Entire home/apt                           1.000000
# room_type_Hotel room                               -0.089751
# room_type_Private room                             -0.956356
# room_type_Shared room                              -0.129928
#
#                                    room_type_Hotel room  \
# Unnamed: 0                                     0.060906
# price                                          0.051978
# minimum_nights                                -0.017870
# availability_365                               0.110591
# number_of_reviews                             -0.017720
# neighbourhood_group_Bronx                     -0.012968
# neighbourhood_group_Brooklyn                  -0.057936
# neighbourhood_group_Manhattan                  0.063810
# neighbourhood_group_Queens                    -0.001757
# neighbourhood_group_Staten Island             -0.007224
# room_type_Entire home/apt                     -0.089751
# room_type_Hotel room                           1.000000
# room_type_Private room                        -0.077329
# room_type_Shared room                         -0.010506
#
#                                    room_type_Private room  \
# Unnamed: 0                                       0.033621
# price                                           -0.576767
# minimum_nights                                  -0.072641
# availability_365                                -0.019904
# number_of_reviews                                0.015984
# neighbourhood_group_Bronx                        0.034487
# neighbourhood_group_Brooklyn                     0.070782
# neighbourhood_group_Manhattan                   -0.138557
# neighbourhood_group_Queens                       0.089872
# neighbourhood_group_Staten Island               -0.005148
# room_type_Entire home/apt                       -0.956356
# room_type_Hotel room                            -0.077329
# room_type_Private room                           1.000000
# room_type_Shared room                           -0.111945
#
#                                    room_type_Shared room
# Unnamed: 0                                      0.022138
# price                                          -0.083990
# minimum_nights                                 -0.009794
# availability_365                                0.026423
# number_of_reviews                              -0.015758
# neighbourhood_group_Bronx                       0.020121
# neighbourhood_group_Brooklyn                   -0.039109
# neighbourhood_group_Manhattan                   0.030024
# neighbourhood_group_Queens                      0.006413
# neighbourhood_group_Staten Island              -0.008309
# room_type_Entire home/apt                      -0.129928
# room_type_Hotel room                           -0.010506
# room_type_Private room                         -0.111945
# room_type_Shared room                           1.000000

# %%
abnb_df_90.to_csv(r'abnb_df_90_ML.csv')

# %%
abnb_df_80.to_csv(r'abnb_df_80_ML.csv')

# %%
abnb_df_50.to_csv(r'abnb_df_50_ML.csv')

# %%
# Create an completely empty Dataframe without any column names, indices or data
abnb_df_corr_comparison = pd.DataFrame(columns=['100_percent', '90_percent', '80_percent','50_percent'],
                                       index=['Unnamed: 0','price', 'minimum_nights', 'availability_365','number_of_reviews',
                                             'neighbourhood_group_Bronx','neighbourhood_group_Brooklyn',
                                              'neighbourhood_group_Manhattan','neighbourhood_group_Queens',
                                              'neighbourhood_group_Staten Island','room_type_Entire home/apt',
                                              'room_type_Hotel room','room_type_Private room','room_type_Shared room'])
abnb_df_corr_comparison['100_percent'] = abnb_df_corr.price
abnb_df_corr_comparison['90_percent'] = abnb_df_90_corr.price
abnb_df_corr_comparison['80_percent'] = abnb_df_80_corr.price
abnb_df_corr_comparison['50_percent'] = abnb_df_50_corr.price
abnb_df_corr_comparison
# Out:
#                                    100_percent  90_percent  80_percent  \
# Unnamed: 0                            0.034164    0.011780   -0.011692
# price                                 1.000000    1.000000    1.000000
# minimum_nights                        0.028448    0.034641    0.048024
# availability_365                      0.064661    0.071160    0.053042
# number_of_reviews                    -0.041879   -0.046004   -0.041855
# neighbourhood_group_Bronx            -0.032118   -0.082383   -0.081743
# neighbourhood_group_Brooklyn         -0.080834   -0.167658   -0.149702
# neighbourhood_group_Manhattan         0.133342    0.303142    0.276600
# neighbourhood_group_Queens           -0.061973   -0.162759   -0.151836
# neighbourhood_group_Staten Island    -0.013201   -0.032106   -0.033320
# room_type_Entire home/apt             0.152405    0.586486    0.587107
# room_type_Hotel room                  0.028210    0.051978    0.036448
# room_type_Private room               -0.146636   -0.576767   -0.577731
# room_type_Shared room                -0.037019   -0.083990   -0.076503
#
#                                    50_percent
# Unnamed: 0                          -0.023225
# price                                1.000000
# minimum_nights                       0.045548
# availability_365                     0.029867
# number_of_reviews                   -0.016281
# neighbourhood_group_Bronx           -0.059300
# neighbourhood_group_Brooklyn        -0.065152
# neighbourhood_group_Manhattan        0.148058
# neighbourhood_group_Queens          -0.095967
# neighbourhood_group_Staten Island   -0.030902
# room_type_Entire home/apt            0.468507
# room_type_Hotel room                 0.010187
# room_type_Private room              -0.459760
# room_type_Shared room               -0.062049

# %%
abnb_df_corr_comparison = abnb_df_corr_comparison.drop(['price'])
abnb_df_corr_comparison
# Out:
#                                    100_percent  90_percent  80_percent  \
# Unnamed: 0                            0.034164    0.011780   -0.011692
# minimum_nights                        0.028448    0.034641    0.048024
# availability_365                      0.064661    0.071160    0.053042
# number_of_reviews                    -0.041879   -0.046004   -0.041855
# neighbourhood_group_Bronx            -0.032118   -0.082383   -0.081743
# neighbourhood_group_Brooklyn         -0.080834   -0.167658   -0.149702
# neighbourhood_group_Manhattan         0.133342    0.303142    0.276600
# neighbourhood_group_Queens           -0.061973   -0.162759   -0.151836
# neighbourhood_group_Staten Island    -0.013201   -0.032106   -0.033320
# room_type_Entire home/apt             0.152405    0.586486    0.587107
# room_type_Hotel room                  0.028210    0.051978    0.036448
# room_type_Private room               -0.146636   -0.576767   -0.577731
# room_type_Shared room                -0.037019   -0.083990   -0.076503
#
#                                    50_percent
# Unnamed: 0                          -0.023225
# minimum_nights                       0.045548
# availability_365                     0.029867
# number_of_reviews                   -0.016281
# neighbourhood_group_Bronx           -0.059300
# neighbourhood_group_Brooklyn        -0.065152
# neighbourhood_group_Manhattan        0.148058
# neighbourhood_group_Queens          -0.095967
# neighbourhood_group_Staten Island   -0.030902
# room_type_Entire home/apt            0.468507
# room_type_Hotel room                 0.010187
# room_type_Private room              -0.459760
# room_type_Shared room               -0.062049

# %%
abnb_df_corr_comparison.to_csv(r'abnb_df_corr_comparison.csv')

# %%
ax = abnb_df_corr_comparison.plot.bar()
ax.figure.savefig('price_corr_diff_percent_sample1.png')

# %%
import seaborn as sns

ax2 = sns.heatmap(abnb_df_90_corr, xticklabels=abnb_df_90_corr.columns,
            yticklabels=abnb_df_90_corr.columns,
            cmap=sns.diverging_palette(220, 10, as_cmap=True))

ax2.figure.savefig('price_corr90_heat_map1.png')

# %%
ax3 = sns.pairplot(abnb_df_90.iloc[round(abnb_nrows*.1):round(abnb_nrows*.9)])
ax3.savefig('price_corr90_pair_plot1.png')
